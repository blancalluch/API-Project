# %%
import requests
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
#data = requests.get('http://localhost:8080/chat/5/sentiment').json()
#data

# %%
import mongoAtlasConnection as mon
db_sent, coll_sent = mon.connectCollection('chat_conversations', 'sentiments')

# %%
query=list(coll_sent.find())
#query

# %%
users=set([q["idUser"] for q in query])
query
# Out:
# [{'_id': ObjectId('5de586e871c4e572a0df4503'),
#   'idUser': 0,
#   'idMessage': 0,
#   'Message': 'Hey Mike, whats up??',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586e871c4e572a0df4504'),
#   'idUser': 1,
#   'idMessage': 1,
#   'Message': 'Dude!!! 😀️ Did you watch the game last night?',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586e871c4e572a0df4505'),
#   'idUser': 0,
#   'idMessage': 2,
#   'Message': 'No, had to work. How was it?',
#   'Sentiment': {'neg': 0.268, 'neu': 0.732, 'pos': 0.0, 'compound': -0.296}},
#  {'_id': ObjectId('5de586e871c4e572a0df4506'),
#   'idUser': 1,
#   'idMessage': 3,
#   'Message': 'Awesome! Boyander scored 3 goals!',
#   'Sentiment': {'neg': 0.0, 'neu': 0.39, 'pos': 0.61, 'compound': 0.6892}},
#  {'_id': ObjectId('5de586e871c4e572a0df4507'),
#   'idUser': 0,
#   'idMessage': 4,
#   'Message': 'No way! 😮️',
#   'Sentiment': {'neg': 0.555, 'neu': 0.445, 'pos': 0.0, 'compound': -0.3595}},
#  {'_id': ObjectId('5de586e871c4e572a0df4508'),
#   'idUser': 1,
#   'idMessage': 5,
#   'Message': 'Way...',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586e871c4e572a0df4509'),
#   'idUser': 0,
#   'idMessage': 6,
#   'Message': 'I bet people went crazy',
#   'Sentiment': {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.34}},
#  {'_id': ObjectId('5de586e871c4e572a0df450a'),
#   'idUser': 1,
#   'idMessage': 7,
#   'Message': 'For sure. We stayed at KuboLoco until 6AM.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.3182}},
#  {'_id': ObjectId('5de586e871c4e572a0df450b'),
#   'idUser': 0,
#   'idMessage': 8,
#   'Message': 'Motherfucker! Hungover? 😵️',
#   'Sentiment': {'neg': 0.71, 'neu': 0.29, 'pos': 0.0, 'compound': -0.7088}},
#  {'_id': ObjectId('5de586e871c4e572a0df450c'),
#   'idUser': 1,
#   'idMessage': 9,
#   'Message': 'Dead, burried and still suffering! 🤮️',
#   'Sentiment': {'neg': 0.658, 'neu': 0.342, 'pos': 0.0, 'compound': -0.8268}},
#  {'_id': ObjectId('5de586ee71c4e572a0df450d'),
#   'idUser': 2,
#   'idMessage': 10,
#   'Message': 'Im so angry right now!',
#   'Sentiment': {'neg': 0.493, 'neu': 0.507, 'pos': 0.0, 'compound': -0.5974}},
#  {'_id': ObjectId('5de586ee71c4e572a0df450e'),
#   'idUser': 3,
#   'idMessage': 11,
#   'Message': 'I saw you this morning. You shouldnt get so upset. ❤️',
#   'Sentiment': {'neg': 0.272, 'neu': 0.728, 'pos': 0.0, 'compound': -0.5214}},
#  {'_id': ObjectId('5de586ee71c4e572a0df450f'),
#   'idUser': 2,
#   'idMessage': 12,
#   'Message': 'Impossible! Cant do it! Just cant! He pissed me off so much.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.6421}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4510'),
#   'idUser': 3,
#   'idMessage': 13,
#   'Message': 'Dont get so frustrated, Leia. Remember what German said.',
#   'Sentiment': {'neg': 0.353, 'neu': 0.647, 'pos': 0.0, 'compound': -0.656}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4511'),
#   'idUser': 2,
#   'idMessage': 14,
#   'Message': 'But how am I suposed to fix the facial recognition system if it doesnt even work?',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4512'),
#   'idUser': 3,
#   'idMessage': 15,
#   'Message': 'Im sure you will find a way.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.685, 'pos': 0.315, 'compound': 0.3182}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4513'),
#   'idUser': 2,
#   'idMessage': 16,
#   'Message': 'And who the hell is Tony? 🤯️',
#   'Sentiment': {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.6808}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4514'),
#   'idUser': 3,
#   'idMessage': 17,
#   'Message': 'I am Iron Man',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4515'),
#   'idUser': 2,
#   'idMessage': 18,
#   'Message': 'Oh shit. I think youre friends with my brother.',
#   'Sentiment': {'neg': 0.283, 'neu': 0.472, 'pos': 0.244, 'compound': -0.128}},
#  {'_id': ObjectId('5de586ee71c4e572a0df4516'),
#   'idUser': 3,
#   'idMessage': 19,
#   'Message': 'Uh-Oh. Better fix that quickly.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}},
#  {'_id': ObjectId('5de586f271c4e572a0df4517'),
#   'idUser': 1,
#   'idMessage': 20,
#   'Message': 'Sweety pie! How Ive longed to talk to you.',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df4518'),
#   'idUser': 4,
#   'idMessage': 21,
#   'Message': 'Not again, Michael.... 😒️',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df4519'),
#   'idUser': 1,
#   'idMessage': 22,
#   'Message': 'Its Mike, honey bunny. Or doctor LOVE! And youre a sick little girl.',
#   'Sentiment': {'neg': 0.178, 'neu': 0.54, 'pos': 0.282, 'compound': 0.4451}},
#  {'_id': ObjectId('5de586f271c4e572a0df451a'),
#   'idUser': 4,
#   'idMessage': 23,
#   'Message': 'Im gonna report you to Human Resources again, Michael.',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df451b'),
#   'idUser': 1,
#   'idMessage': 24,
#   'Message': 'Cant handle me on your own?',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df451c'),
#   'idUser': 4,
#   'idMessage': 25,
#   'Message': 'Id rather have a fucking alien crawling out of my ass',
#   'Sentiment': {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compound': -0.5423}},
#  {'_id': ObjectId('5de586f271c4e572a0df451d'),
#   'idUser': 1,
#   'idMessage': 26,
#   'Message': 'That would be hot... 🔥️',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df451e'),
#   'idUser': 4,
#   'idMessage': 27,
#   'Message': 'Ok, youve got to stop drinking! Im calling HR.',
#   'Sentiment': {'neg': 0.193, 'neu': 0.614, 'pos': 0.193, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f271c4e572a0df451f'),
#   'idUser': 1,
#   'idMessage': 28,
#   'Message': 'I NEED VODKA LIKE A CAR NEEDS GAS',
#   'Sentiment': {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}},
#  {'_id': ObjectId('5de586f271c4e572a0df4520'),
#   'idUser': 4,
#   'idMessage': 29,
#   'Message': 'Dude... Alcoholics Anonymous: https://www.aa.org',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f471c4e572a0df4521'),
#   'idUser': 5,
#   'idMessage': 30,
#   'Message': 'I want pictures of Spiderman and I want them now!',
#   'Sentiment': {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.2244}},
#  {'_id': ObjectId('5de586f471c4e572a0df4522'),
#   'idUser': 0,
#   'idMessage': 31,
#   'Message': 'Sure, boss.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.3182}},
#  {'_id': ObjectId('5de586f471c4e572a0df4523'),
#   'idUser': 5,
#   'idMessage': 32,
#   'Message': 'Youve got to take me seriously.',
#   'Sentiment': {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.1779}},
#  {'_id': ObjectId('5de586f471c4e572a0df4524'),
#   'idUser': 0,
#   'idMessage': 33,
#   'Message': 'I do! I just dont feel appreciated in my job',
#   'Sentiment': {'neg': 0.3, 'neu': 0.7, 'pos': 0.0, 'compound': -0.4577}},
#  {'_id': ObjectId('5de586f471c4e572a0df4525'),
#   'idUser': 5,
#   'idMessage': 34,
#   'Message': 'Thats why youve got to get those damm pictures!!',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f471c4e572a0df4526'),
#   'idUser': 0,
#   'idMessage': 35,
#   'Message': 'I dunno...',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f471c4e572a0df4527'),
#   'idUser': 5,
#   'idMessage': 36,
#   'Message': 'Get the god damn motherfucking fuckity fuck bloody ballsack pictures',
#   'Sentiment': {'neg': 0.645, 'neu': 0.25, 'pos': 0.105, 'compound': -0.8957}},
#  {'_id': ObjectId('5de586f471c4e572a0df4528'),
#   'idUser': 0,
#   'idMessage': 37,
#   'Message': 'Maybe',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f471c4e572a0df4529'),
#   'idUser': 5,
#   'idMessage': 38,
#   'Message': 'Youve got to! And I believe in you',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f471c4e572a0df452a'),
#   'idUser': 0,
#   'idMessage': 39,
#   'Message': 'Thank you, boss! I feel much better...',
#   'Sentiment': {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.4199}},
#  {'_id': ObjectId('5de586f871c4e572a0df452b'),
#   'idUser': 6,
#   'idMessage': 40,
#   'Message': 'REDRUM',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f871c4e572a0df452c'),
#   'idUser': 7,
#   'idMessage': 41,
#   'Message': 'What was that?',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f871c4e572a0df452d'),
#   'idUser': 6,
#   'idMessage': 42,
#   'Message': 'REDRUM REDRUM REDRUM',
#   'Sentiment': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}},
#  {'_id': ObjectId('5de586f871c4e572a0df452e'),
#   'idUser': 7,
#   'idMessage': 43,
#   'Message': 'Did you mean red room? Id love a red room.',
#   'Sentiment': {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'compound': 0.6369}},
#  {'_id': ObjectId('5de586f871c4e572a0df452f'),
#   'idUser': 6,
#   'idMessage': 44,
#   'Message': 'Murder, bro, cold blooded splashy murderous fun',
#   'Sentiment': {'neg': 0.549, 'neu': 0.247, 'pos': 0.204, 'compound': -0.765}},
#  {'_id': ObjectId('5de586f871c4e572a0df4530'),
#   'idUser': 7,
#   'idMessage': 45,
#   'Message': 'Chill out, pinky.. Its such a nice day',
#   'Sentiment': {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}},
#  {'_id': ObjectId('5de586f871c4e572a0df4531'),
#   'idUser': 6,
#   'idMessage': 46,
#   'Message': 'A nice day to create havoc!',
#   'Sentiment': {'neg': 0.352, 'neu': 0.18, 'pos': 0.468, 'compound': 0.0752}},
#  {'_id': ObjectId('5de586f871c4e572a0df4532'),
#   'idUser': 7,
#   'idMessage': 47,
#   'Message': 'Ill go for a walk in the park, I guess. Maybe fishing',
#   'Sentiment': {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.4215}},
#  {'_id': ObjectId('5de586f871c4e572a0df4533'),
#   'idUser': 6,
#   'idMessage': 48,
#   'Message': 'Fishing sounds good. What about the labyrinth?',
#   'Sentiment': {'neg': 0.0, 'neu': 0.674, 'pos': 0.326, 'compound': 0.4404}},
#  {'_id': ObjectId('5de586f871c4e572a0df4534'),
#   'idUser': 7,
#   'idMessage': 49,
#   'Message': 'No! That places creeps me out..',
#   'Sentiment': {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0